# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import pandas as pd
import numpy as np
# %matplotlib inline
data = pd.read_csv("TotalTrafo.csv")

# %%
print(data)
# Out:
#               datetime  Trafo1  Trafo2  Trafo_Total  Month  Day  Hour  \
# 0      2018-03-26 0:00   29.31   17.86        47.17      3    2     0
# 1      2018-03-26 1:00   29.06   19.58        48.64      3    2     1
# 2      2018-03-26 2:00   30.40   18.18        48.58      3    2     2
# 3      2018-03-26 3:00   30.02   16.83        46.85      3    2     3
# 4      2018-03-26 4:00   30.91   17.54        48.45      3    2     4
# ...                ...     ...     ...          ...    ...  ...   ...
# 8755  2019-03-25 19:00   49.54   26.88        76.42      3    2    19
# 8756  2019-03-25 20:00   42.37   20.86        63.23      3    2    20
# 8757  2019-03-25 21:00   40.58   12.54        53.12      3    2    21
# 8758  2019-03-25 22:00   38.14   20.61        58.75      3    2    22
# 8759  2019-03-25 23:00   29.18   17.41        46.59      3    2    23
#
#       Workday  Min_Temp  Max_Temp  Feels_Like  Pressure  Humidity  Wind Speed
# ...

# %%
from sklearn.preprocessing import StandardScaler
cols_to_norm = ['Trafo1','Trafo2','Trafo_Total','Month',"Day",'Hour','Workday','Min_Temp','Max_Temp','Feels_Like','Pressure','Humidity','Wind Speed']
data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])

# %%
print(data)
# Out:
#               datetime    Trafo1    Trafo2  Trafo_Total     Month       Day  \
# 0      2018-03-26 0:00 -0.804145 -0.821304    -0.861889 -1.022674 -0.997264
# 1      2018-03-26 1:00 -0.818924 -0.751013    -0.824293 -1.022674 -0.997264
# 2      2018-03-26 2:00 -0.739708 -0.808227    -0.825828 -1.022674 -0.997264
# 3      2018-03-26 3:00 -0.762172 -0.863397    -0.870073 -1.022674 -0.997264
# 4      2018-03-26 4:00 -0.709559 -0.834382    -0.829152 -1.022674 -0.997264
# ...                ...       ...       ...          ...       ...       ...
# 8755  2019-03-25 19:00  0.391778 -0.452686    -0.113808 -1.022674 -0.997264
# 8756  2019-03-25 20:00 -0.032086 -0.698704    -0.451148 -1.022674 -0.997264
# 8757  2019-03-25 21:00 -0.137904 -1.038715    -0.709715 -1.022674 -0.997264
# 8758  2019-03-25 22:00 -0.282148 -0.708921    -0.565726 -1.022674 -0.997264
# 8759  2019-03-25 23:00 -0.811830 -0.839694    -0.876723 -1.022674 -0.997264
#
# ...

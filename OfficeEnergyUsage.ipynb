# %% [markdown]
# # Welcome to our Office Energy Usage Prediction Model!!
#
# ### Input Data
# We were provided with two input datasheets: Trafo1.csv and Trafo2.csv.
# The Office Energy Usage_Workbook.xlsx in our Githhub repository shows the data cleaning process and provides the output to a new .csv file named TotalTrafo.csv which uses clean data fom 26 March 2018 0:00 up to and inclusive of 26 March 2019 23:00.
#
# ### Notes
# Months go from 1 to 12 (January to December)
#
# Weekday goes from 1 to 7 (Sunday to Saturday)
#
# Time is by hour of the day in 24 hour time clock

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

EnergyUse = pd.read_csv("TotalTrafo.csv")

column_info = pd.DataFrame.head(EnergyUse)

column_info
# Out:
#           datetime  Trafo1  Trafo2  Trafo_Total  Month  Day  Hour  Workday
# 0  2018-03-26 0:00   29.31   17.86        47.17      3    2     0        1
# 1  2018-03-26 1:00   29.06   19.58        48.64      3    2     1        1
# 2  2018-03-26 2:00   30.40   18.18        48.58      3    2     2        1
# 3  2018-03-26 3:00   30.02   16.83        46.85      3    2     3        1
# 4  2018-03-26 4:00   30.91   17.54        48.45      3    2     4        1

# %%
data_info = pd.DataFrame.info(EnergyUse)

data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     8760 non-null   object
#  1   Trafo1       8760 non-null   float64
#  2   Trafo2       8760 non-null   float64
#  3   Trafo_Total  8760 non-null   float64
#  4   Month        8760 non-null   int64
#  5   Day          8760 non-null   int64
#  6   Hour         8760 non-null   int64
#  7   Workday      8760 non-null   int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 547.6+ KB

# %%
EnergyPlot = sns.pairplot(EnergyUse)
